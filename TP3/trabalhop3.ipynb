# %%
import random

def jogador(): 
    fosforos=21
    
    while fosforos>0:
        n=int(input("Quantos fósforos queres tirar?"))
        if n>4 or n<1:
            print("Número inválido")
        elif n>fosforos:
            print(f"Só existem {fosforos},joga outra vez")
        else:
            fosforos=fosforos-n 
            print(f"Tiraste {n} fósforos. Restam {fosforos} fósforos")
            if fosforos<=0:
                print("Perdeste.O computador ganhou")
            else:
                comp=5-n
                print(f"O computador tira {comp} fósforos")
                fosforos=fosforos-comp
                print(f"Restam {fosforos} fósforos")


def computador():
    fosforos = 21
    erro = 1
    comp = random.randint(1,4)
    fosforos = fosforos - comp
    print(f"O computador tirou {comp} fósforos.Restam {fosforos} fosforos")
    
    
    while fosforos>0:
        
        n = int(input("Quantos fosforos queres tirar?"))

        if n>4 or n<1:
            print("Número inválido")
        elif n>fosforos:
            print(f"Só existem {fosforos}, joga outra vez")
        else:
            fosforos = fosforos - n
            print(f"Tiraste {n} fosforos. Restam {fosforos} fosforos")
            if fosforos<=0:
                print("Perdeste.O computador ganhou")
            elif fosforos==1:
                print(f"O computador tirou 1 fósforo. Restam 0 fósforos. O computador perdeu.")
                fosforos=0
            else:
                if n+comp!=5 and erro==1:
                    if n+comp<5:
                        comp=5-(n+comp)
                    else:
                        comp=10-(n+comp)
                    erro=0
                else:
                    comp=5-n

                fosforos = fosforos - comp
                print(f"O computador tirou {comp} fósforos.Restam {fosforos} fosforos")



print("Que jogo queres jogar?")
print("1 - Tu começas")
print("2 - O computador começa")
opcao = input()
if opcao=="1":
    jogador()
elif opcao=="2":
    computador()
# Out:
# Que jogo queres jogar?
# 1 - Tu começas
# 2 - O computador começa
# O computador tirou 3 fósforos.Restam 18 fosforos
# Tiraste 4 fosforos. Restam 14 fosforos
# O computador tirou 3 fósforos.Restam 11 fosforos
# Tiraste 3 fosforos. Restam 8 fosforos
# O computador tirou 2 fósforos.Restam 6 fosforos
# Tiraste 3 fosforos. Restam 3 fosforos
# O computador tirou 2 fósforos.Restam 1 fosforos
# Tiraste 1 fosforos. Restam 0 fosforos
# Perdeste.O computador ganhou
